# %% [markdown]
# LetsGrowMore Virtual Internship(LGMVIP) DataScience (OCTOBER-2022)
#
# NAME : KARRA VIVEK REDDY
#
# Beginner Level Task
#
# Task 4 : Image to Pencil Sketch with Python

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
image = cv2.imread("Karra Vivek Reddy.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=276x354 at 0x7FA8E7BB6B50>

# %%
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=276x354 at 0x7FA8E73106D0>

# %%
inverted_image = 255 - image_gray
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=276x354 at 0x7FA8E7310CD0>

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=276x354 at 0x7FA8DEB8DD50>

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(image_gray, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=276x354 at 0x7FA8DEB81BD0>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=276x354 at 0x7FA8DE348B90>
# <PIL.Image.Image image mode=L size=276x354 at 0x7FA8DE33AC10>
